# %%
#!pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/2b/31/cc5cf31258dc2cbb50dd1b046164add33804eab7af036d86aa68d45c7f6c/opencv_python-3.4.1.15-cp36-cp36m-win_amd64.whl (33.6MB)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\ellys\anaconda3\lib\site-packages (from opencv-python) (1.13.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-3.4.1.15

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('alice.jpg')

# %%
kernel = np.array([[0,0,0],[0,1,0],[0,0,0]],np.float32) / 9
dst = cv2.filter2D(img1,-1,kernel)

# %%
plt.imshow(img1)
plt.title('Initial Image')
plt.show()

plt.imshow(dst)
plt.title('Blurred Image')
plt.show()

# %%
cv2.namedWindow("dst")
cv2.imshow('dst',dst)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.namedWindow("image")
cv2.imshow('image',img1)
cv2.waitKey(0)
# Out:
# -1

# %%
img2 = cv2.imread('krug.png')
img2_gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

equ = cv2.equalizeHist(img2_gray)

# %%
hist,bins = np.histogram(img2.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()
 
plt.plot(cdf_normalized, color = 'b')
plt.hist(img2.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
X = np.load('X.npy')
Y = np.load('Y.npy')
X_test = np.load('X_test.npy')
Y_test = np.load('Y_test.npy')

# %%
from sklearn.svm import SVC

# %%
estimator = SVC(random_state=0)
estimator.fit(X, Y)

preds = estimator.predict(X_test)

# %%
def write_answer_3(x):
    with open("answer3.txt", "w") as fout:
        fout.write(str(x))

# %%
write_answer_3(np.sum(preds == Y_test))
